# %%
data={
  "P001": {
    "name": "Ananya Sharma",
    "city": "Mumbai",
    "age": 20,
    "gender": "Female",
    "height": 1.65,
    "weight": 90.0,
    "bmi": 33.0,
    "verdict": "obese"
  },
  "P002": {
    "name": "Rajat Singh",
    "city": "Delhi",
    "age": 22,
    "gender": "Male",
    "height": 1.80,
    "weight": 75.0,
    "bmi": 23.1,
    "verdict": "normal"
  },
  "P003": {
    "name": "Priya Verma",
    "city": "Bangalore",
    "age": 19,
    "gender": "Female",
    "height": 1.55,
    "weight": 60.0,
    "bmi": 24.9,
    "verdict": "normal"
  }
}

# %%
sorted_data=sorted(data)
